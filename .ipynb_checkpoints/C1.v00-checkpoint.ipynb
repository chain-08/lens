# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
TICKER = 'NIFTYBEES.NSE'
EODHD_API_KEY = "67ad1bea200726.95055451"

# %%
#url = f'https://eodhd.com/api/eod/{TICKER}?api_token={EODHD_API_KEY}&period=d&fmt=json'

start_date = (datetime.now() - timedelta(days=100)).strftime('%Y-%m-%d')
url = f'https://eodhd.com/api/eod/{TICKER}?api_token={EODHD_API_KEY}&from={start_date}&period=d&fmt=json'

# %%
response = requests.get(url)
df = pd.DataFrame(response.json())

print(df)
# Out:
#           date    open    high     low   close  adjusted_close    volume
# 0   2025-01-06  268.05  269.60  263.61  264.48          264.48   8357958
# 1   2025-01-07  266.25  266.25  263.71  265.16          265.16   3881642
# 2   2025-01-08  265.95  266.04  262.80  264.92          264.92   5056466
# 3   2025-01-09  264.75  265.50  262.90  263.15          263.15   3929443
# 4   2025-01-10  263.25  263.87  261.15  262.22          262.22   4496919
# ..         ...     ...     ...     ...     ...             ...       ...
# 62  2025-04-04  260.48  260.58  256.48  257.16          257.16   9233464
# 63  2025-04-07  264.85  264.85  231.30  249.10          249.10  34654934
# 64  2025-04-08  256.55  256.55  249.76  252.72          252.72   9860513
# 65  2025-04-09  251.72  252.68  250.62  251.03          251.03   7144236
# 66  2025-04-11  255.99  256.90  251.23  255.97          255.97  10802170
#
# [67 rows x 7 columns]
