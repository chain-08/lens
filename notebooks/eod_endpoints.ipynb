# %%
import pandas as pd
import requests

API_KEY = "67ad1bea200726.95055451"
BASE_URL = "https://eodhd.com/api"

# %% [markdown]
# ## List all supported exchanges

# %%
url = f"{BASE_URL}/exchanges-list/?api_token={API_KEY}&fmt=json"
resp = requests.get(url)
df_exchanges = pd.DataFrame(resp.json())
df_exchanges.head()
# Out:
#                    Name Code      OperatingMIC Country Currency CountryISO2  \
# 0            USA Stocks   US  XNAS, XNYS, OTCM     USA      USD          US
# 1       London Exchange  LSE              XLON      UK      GBP          GB
# 2          NEO Exchange  NEO              NEOE  Canada      CAD          CA
# 3  TSX Venture Exchange    V              XTSX  Canada      CAD          CA
# 4      Toronto Exchange   TO              XTSE  Canada      CAD          CA
#
#   CountryISO3
# 0         USA
# 1         GBR
# 2         CAN
# 3         CAN
# 4         CAN

# %% [markdown]
# ## List all tickers on US exchange
