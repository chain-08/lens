# %%
import clickhouse_connect

# %%
CLICKHOUSE_HOST = '54.234.38.203'
CLICKHOUSE_PORT = 8123
CLICKHOUSE_USER = 'chain8'
CLICKHOUSE_PASS = 'c8_2025'
CLICKHOUSE_DB = 'default'

# %%
client = clickhouse_connect.get_client(
    host=CLICKHOUSE_HOST,
    port=CLICKHOUSE_PORT,
    username=CLICKHOUSE_USER,
    password=CLICKHOUSE_PASS,
    database=CLICKHOUSE_DB
)

# %%
df_tsx = client.query_df("""
    SELECT *
    FROM tsx_eod
""")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_tsx = client.query_df("""
#       2     SELECT *
#       3     FROM tsx_eod
#       4 """)
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/client.py:350, in Client.query_df(self, query, parameters, settings, query_formats, column_formats, encoding, use_none, max_str_len, use_na_values, query_tz, column_tzs, context, external_data, use_extended_dtypes)
#     330 def query_df(self,
#     331              query: Optional[str] = None,
#     332              parameters: Optional[Union[Sequence, Dict[str, Any]]] = None,
#    (...)
#     343              external_data: Optional[ExternalData] = None,
#     344              use_extended_dtypes: Optional[bool] = None):
#     345     """
#     346     Query method that results the results as a pandas dataframe.  For parameter values, see the
#     347     create_query_context method
#     348     :return: Pandas dataframe representing the result set
#     349     """
# --> 350     return self._context_query(locals(), use_numpy=True, as_pandas=True).df_result
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/client.py:774, in Client._context_query(self, lcls, **overrides)
#     772 kwargs.pop('self')
#     773 kwargs.update(overrides)
# --> 774 return self._query_with_context((self.create_query_context(**kwargs)))
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/httpclient.py:214, in HttpClient._query_with_context(self, context)
#     212     fields = None
#     213     headers['Content-Type'] = 'text/plain; charset=utf-8'
# --> 214 response = self._raw_request(body,
#     215                              params,
#     216                              headers,
#     217                              stream=True,
#     218                              retries=self.query_retries,
#     219                              fields=fields,
#     220                              server_wait=not context.streaming)
#     221 byte_source = RespBuffCls(ResponseSource(response))  # pylint: disable=not-callable
#     222 context.set_response_tz(self._check_tz_change(response.headers.get('X-ClickHouse-Timezone')))
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/httpclient.py:438, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler)
#     436     error_handler(response)
#     437 else:
# --> 438     self._error_handler(response)
#
# File /opt/conda/lib/python3.11/site-packages/clickhouse_connect/driver/httpclient.py:362, in HttpClient._error_handler(self, response, retried)
#     360     err_msg = common.format_error(err_content.decode(errors='backslashreplace'))
#     361     err_str = f':{err_str}\n {err_msg}'
# --> 362 raise OperationalError(err_str) if retried else DatabaseError(err_str) from None
#
# DatabaseError: :HTTPDriver for http://54.234.38.203:8123 returned response code 404)
#  Code: 60. DB::Exception: Table default.tsx_eod does not exist. (UNKNOWN_TABLE) (version 23.8.16.16 (official build))

# %%
df_AAPL = df_tsx[df_tsx['code']=="AAPL"].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_AAPL = df_tsx[df_tsx['code']=="AAPL"].copy()
#
# NameError: name 'df_tsx' is not defined

# %%
df_AAPL = df_AAPL.sort_values(by='date').reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_AAPL = df_AAPL.sort_values(by='date').reset_index(drop=True)
#
# NameError: name 'df_AAPL' is not defined

# %%
df_AAPL['exit'] = (
    df_AAPL['open'] * 1.01
).round(2).where(
    df_AAPL['high'] > df_AAPL['open'] * 1.01, 
    df_AAPL['close']
)

# %%
df_AAPL['model_return_pct'] = ((df_AAPL['exit'] / df_AAPL['open']) - 1) * 100

# %%
df_AAPL

# %% [markdown]
# # import plotly.express as px
#
# fig = px.line(df_AAPL, x='date', y='model_return_pct')
# fig.update_layout(showlegend=False, xaxis_title=None, yaxis_title=None, title=None)
# fig.show()

# %%
df_AAPL['cumulative_return'] = (1 + df_AAPL['model_return_pct'] / 100).cumprod()

# %%
df_AAPL
